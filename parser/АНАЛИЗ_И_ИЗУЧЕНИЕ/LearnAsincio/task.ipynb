# %% [markdown]
# # Задание спарсить сайт: https://fitaudit.ru/categories/fds
# Используя многопоточность aiohttp, aiofiles и BeautifulSoup при желании совместить это все с многопроцессорностью multiprocessing.Process().

# %%
import asyncio
import aiohttp
import aiofiles
import requests
from multiprocessing import Process
from typing import Dict, Any, Union
import os
from fake_useragent import UserAgent
from bs4 import BeautifulSoup

# %%
def get_html_file(url: str, path: str, file_name:str = "file.txt", header: Dict[str, str] = None) -> bool:
    """
    Функция которая создает файл с html разметкой сайта `url`

    Args:
        url (str): URL
        header (Dict[str, str], optional): Http-header. Defaults to None.
        file_name (str): С каким названием создать файл? Default to file.txt
        path (str): Путь по которому сохранять файл

    Returns:
        bool: Получилось ли создать файл?
    """
    html = None
    all_path = os.path.join(path, 'data')

    with requests.get(url= url, 
                      headers= header) as resp:
        print(f"Закончил парсить сайт {resp.url}")
        html = resp.text

    if not os.path.isdir(all_path):
        os.mkdir(all_path)

    key = False
    file_path = os.path.join(all_path, file_name)
    try:
        with open(file_path, 'w') as f:
            f.write(html)
            key= True

    except:
        print("Не удалось записать в файл данные!")
        raise

    finally:
        return key

# %%
def read_html_file_and_get_href(path: str) -> Dict[str, str]:
    """
    Читает все в файле и формирует json

    Args:
        path (str): путь к файлу, который нужно спарсить

    Returns:
        Dict[str, str]: json НАЗВАНИЕ ПРОДУКТА = ссылка на продукт
    """
    data = None
    with open(path) as f:
        data = f.read() 

    soup = BeautifulSoup(markup= data, 
                         features= 'lxml')
    product_list = soup.find(name= 'div', attrs= {"id" : "frts"}).next_sibling.next_sibling.find_all('li')
    json = dict() 
    for product in product_list:
        item_name = product.find('a').get('title')
        item_href = product.find('a').get('href')
        json[item_name] = item_href

    return json

# %%
async def create_fruits_file(fruit_name: str, path: str, data: Any) -> str:
    
    file_path = os.path.join(path, fruit_name.capitalize() + ".html") 
    print(file_path)
    try:
        async with aiofiles.open(file_path, 'w') as file:
            await file.write(data)

    except:
        print("Что-то пошло не так, при записе файла")
        raise

# %%
async def get_html(session: aiohttp.ClientSession, href: str) -> Union[None, str]:
    html = None
    try:
        async with session.get(href) as response:
            html = await response.text()
    except:
        print(f"Что-то пошло не так при получении данных из html страницы {href}")
        raise
    finally:
        return html

# %%
async def main():
    url = "https://fitaudit.ru/categories/fds"
    user = UserAgent().random
    header = {'Accept' : "*/*", 
              'user-agent' : user}
    path = os.getcwd()
    file_name = "fruits.html"

    get_html_file(url= url,
                  path= path,
                  file_name= file_name,
                  header= header)
    
    fruit_href = read_html_file_and_get_href(os.path.join(path, 'data', file_name))
    print(fruit_href)
    hrefs = fruit_href.values()
    fruits = fruit_href.keys()


    get_html_tasks =[] 
    async with aiohttp.ClientSession() as session: 
        for href in hrefs:
            task = asyncio.create_task(get_html(session= session, href= href))
            get_html_tasks.append(task)
    
        data = await asyncio.gather(*get_html_tasks)

    create_files_tasks = []
    
    if len(data) != len(fruits):
        print('Количество фруктов не совпало с количеством html-страниц')
        return "ОШИБКА!"
    
    else:
        for fruit, d in zip(fruits, data):
            task = asyncio.create_task(create_fruits_file(fruit_name= fruit, path= os.path.join(path, 'data'), data= d))

        files_path = await asyncio.gather(*create_files_tasks)
        
await main()
# Out:
# Закончил парсить сайт https://fitaudit.ru/categories/fds
# {'Абрикос (свежий)': 'https://fitaudit.ru/food/114512', 'Абрикосы (консервированные)': 'https://fitaudit.ru/food/115520', 'Айва (свежая)': 'https://fitaudit.ru/food/114337', 'Апельсины (свежие)': 'https://fitaudit.ru/food/114159', 'Арбуз (свежий)': 'https://fitaudit.ru/food/114427', 'Бананы (свежие)': 'https://fitaudit.ru/food/114679', 'Гранат (свежий)': 'https://fitaudit.ru/food/114307', 'Грейпфрут (свежий)': 'https://fitaudit.ru/food/114885', 'Груша (консервированная)': 'https://fitaudit.ru/food/115671', 'Груша (свежая)': 'https://fitaudit.ru/food/114205', 'Груша Конференция (свежая)': 'https://fitaudit.ru/food/115791', 'Дыня (свежая)': 'https://fitaudit.ru/food/114001', 'Дыня Канталупа (свежая)': 'https://fitaudit.ru/food/114092', 'Инжир (свежий)': 'https://fitaudit.ru/food/114716', 'Киви (свежий)': 'https://fitaudit.ru/food/114993', 'Лайм (свежий)': 'https://fitaudit.ru/food/114926', 'Лимон (свежий, без кожуры)': 'https://fitaudit.ru/food/114909', 'Мандарины (свежие)': 'https://fitaudit.ru/food/114103', 'Маслины (консервированные)': 'https://fitaudit.ru/food/114031', 'Нектарины (свежие)': 'https://fitaudit.ru/food/114022', 'Оливки зелёные (консервированные)': 'https://fitaudit.ru/food/114034', 'Персик (свежие, без косточек)': 'https://fitaudit.ru/food/114257', 'Персики консервированные': 'https://fitaudit.ru/food/115669', 'Слива (свежая)': 'https://fitaudit.ru/food/114386', 'Хурма (свежая)': 'https://fitaudit.ru/food/114244', 'Цедра апельсина (кожура) (свежая)': 'https://fitaudit.ru/food/114197', 'Цедра лимона (кожура) (свежая)': 'https://fitaudit.ru/food/114917', 'Яблоки (свежие)': 'https://fitaudit.ru/food/114558', 'Яблоки (запечённые)': 'https://fitaudit.ru/food/114567', 'Яблоки Голден (свежие)': 'https://fitaudit.ru/food/115052', 'Яблоки зелёные (Гренни Смит) (свежие)': 'https://fitaudit.ru/food/115055', 'Яблоки красные (свежие)': 'https://fitaudit.ru/food/115059', 'Яблочное варенье (консервированное)': 'https://fitaudit.ru/food/114573'}
# []
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Абрикос (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Абрикосы (консервированные).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Айва (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Апельсины (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Арбуз (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Бананы (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Гранат (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Грейпфрут (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Груша (консервированная).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Груша (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Груша конференция (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Дыня (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Дыня канталупа (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Инжир (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Киви (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Лайм (свежий).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Лимон (свежий, без кожуры).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Мандарины (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Маслины (консервированные).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Нектарины (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Оливки зелёные (консервированные).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Персик (свежие, без косточек).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Персики консервированные.html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Слива (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Хурма (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Цедра апельсина (кожура) (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Цедра лимона (кожура) (свежая).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Яблоки (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Яблоки (запечённые).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Яблоки голден (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Яблоки зелёные (гренни смит) (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Яблоки красные (свежие).html
# /home/ranil/Рабочий стол/Project/LearnAsincio/data/Яблочное варенье (консервированное).html
